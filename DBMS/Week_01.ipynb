# %% [markdown]
# # Machine Learning
#
# Machine Learning is basically making machine reconised pattern in data.
#
# ### Tpyes of Machine Learning
#
# Based on classification there are four types of Machine Learning
